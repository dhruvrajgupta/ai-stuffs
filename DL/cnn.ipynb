# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
cd gdrive/My Drive/AtoZ/Deep_Learning_A_Z/Convolutional_Neural_Networks
# Out:
# /content/gdrive/My Drive/AtoZ/Deep_Learning_A_Z/Convolutional_Neural_Networks

# %%
# Part 1 - Building the CNN
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense

classifier = Sequential()

classifier.add(Conv2D(32, (3, 3), input_shape=(128,128,3), activation='relu'))

classifier.add(MaxPooling2D(pool_size=(2,2)))

classifier.add(Conv2D(32, (3, 3), activation='relu'))

classifier.add(MaxPooling2D(pool_size=(2,2)))

classifier.add(Conv2D(32, (3, 3), activation='relu'))

classifier.add(MaxPooling2D(pool_size=(2,2)))

classifier.add(Flatten())

classifier.add(Dense(units = 128, activation = 'relu'))

classifier.add(Dense(units = 1, activation = 'sigmoid'))

classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy',
                   metrics = ['accuracy'])
print(classifier.summary());
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 126, 126, 32)      896
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 61, 61, 32)        9248
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 28, 28, 32)        9248
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               802944
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 822,465
# Trainable params: 822,465
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Ftting the CNN to the images
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
training_set = train_datagen.flow_from_directory(
                                        'dataset/training_set',
                                        target_size=(128, 128),
                                        batch_size=32,
                                        class_mode='binary')

test_set = test_datagen.flow_from_directory(
                                        'dataset/test_set',
                                        target_size=(128, 128),
                                        batch_size=32,
                                        class_mode='binary')
# Out:
# Found 8000 images belonging to 2 classes.
# Found 2010 images belonging to 2 classes.

# %%
# !pip install -q h5py pyyaml

# %%
import os
import tensorflow as tf

checkpoint_path = "cp/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create checkpoint callback
cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

classifier.fit_generator(
                    training_set,
                    steps_per_epoch=8000/32,
                    epochs=25,
                    validation_data=test_set,
                    validation_steps=2010/32,
                    callbacks = [cp_callback])
# Out:
# Epoch 1/25
# 250/250 [==============================] - 80s 322ms/step - loss: 0.6932 - acc: 0.5166 - val_loss: 0.6574 - val_acc: 0.6229
#
# Epoch 00001: saving model to cp/cp.ckpt
# Epoch 2/25
# 250/250 [==============================] - 77s 307ms/step - loss: 0.6405 - acc: 0.6216 - val_loss: 0.5983 - val_acc: 0.6851
#
# Epoch 00002: saving model to cp/cp.ckpt
# Epoch 3/25
# 250/250 [==============================] - 77s 309ms/step - loss: 0.5828 - acc: 0.6894 - val_loss: 0.5341 - val_acc: 0.7239
#
# Epoch 00003: saving model to cp/cp.ckpt
# Epoch 4/25
# 250/250 [==============================] - 77s 307ms/step - loss: 0.5486 - acc: 0.7198 - val_loss: 0.5457 - val_acc: 0.7264
#
# Epoch 00004: saving model to cp/cp.ckpt
# Epoch 5/25
# 250/250 [==============================] - 78s 311ms/step - loss: 0.5243 - acc: 0.7436 - val_loss: 0.4986 - val_acc: 0.7448
#
# Epoch 00005: saving model to cp/cp.ckpt
# Epoch 6/25
# 250/250 [==============================] - 77s 309ms/step - loss: 0.4892 - acc: 0.7611 - val_loss: 0.5547 - val_acc: 0.7254
#
# Epoch 00006: saving model to cp/cp.ckpt
# Epoch 7/25
# 250/250 [==============================] - 78s 312ms/step - loss: 0.4682 - acc: 0.7749 - val_loss: 0.4492 - val_acc: 0.8020
#
# Epoch 00007: saving model to cp/cp.ckpt
# Epoch 8/25
# 250/250 [==============================] - 77s 307ms/step - loss: 0.4368 - acc: 0.7984 - val_loss: 0.4609 - val_acc: 0.7871
#
# Epoch 00008: saving model to cp/cp.ckpt
# Epoch 9/25
# 250/250 [==============================] - 77s 309ms/step - loss: 0.4159 - acc: 0.8070 - val_loss: 0.4719 - val_acc: 0.7856
#
# Epoch 00009: saving model to cp/cp.ckpt
# Epoch 10/25
# 250/250 [==============================] - 78s 310ms/step - loss: 0.4058 - acc: 0.8164 - val_loss: 0.4172 - val_acc: 0.8149
#
# Epoch 00010: saving model to cp/cp.ckpt
# Epoch 11/25
# 250/250 [==============================] - 77s 309ms/step - loss: 0.3941 - acc: 0.8209 - val_loss: 0.4094 - val_acc: 0.8224
#
# Epoch 00011: saving model to cp/cp.ckpt
# Epoch 12/25
# 250/250 [==============================] - 77s 309ms/step - loss: 0.3786 - acc: 0.8295 - val_loss: 0.4179 - val_acc: 0.8224
#
# Epoch 00012: saving model to cp/cp.ckpt
# Epoch 13/25
# 250/250 [==============================] - 78s 310ms/step - loss: 0.3788 - acc: 0.8271 - val_loss: 0.3880 - val_acc: 0.8279
#
# Epoch 00013: saving model to cp/cp.ckpt
# Epoch 14/25
# 250/250 [==============================] - 77s 310ms/step - loss: 0.3649 - acc: 0.8345 - val_loss: 0.3868 - val_acc: 0.8264
#
# Epoch 00014: saving model to cp/cp.ckpt
# Epoch 15/25
# 250/250 [==============================] - 78s 312ms/step - loss: 0.3554 - acc: 0.8440 - val_loss: 0.3898 - val_acc: 0.8299
#
# Epoch 00015: saving model to cp/cp.ckpt
# Epoch 16/25
# 250/250 [==============================] - 77s 309ms/step - loss: 0.3404 - acc: 0.8475 - val_loss: 0.4194 - val_acc: 0.8060
#
# Epoch 00016: saving model to cp/cp.ckpt
# Epoch 17/25
# 250/250 [==============================] - 78s 310ms/step - loss: 0.3363 - acc: 0.8506 - val_loss: 0.3845 - val_acc: 0.8353
#
# Epoch 00017: saving model to cp/cp.ckpt
# Epoch 18/25
# 250/250 [==============================] - 77s 310ms/step - loss: 0.3248 - acc: 0.8539 - val_loss: 0.3705 - val_acc: 0.8383
#
# Epoch 00018: saving model to cp/cp.ckpt
# Epoch 19/25
# 250/250 [==============================] - 78s 311ms/step - loss: 0.3163 - acc: 0.8626 - val_loss: 0.3940 - val_acc: 0.8284
#
# Epoch 00019: saving model to cp/cp.ckpt
# Epoch 20/25
# 250/250 [==============================] - 77s 309ms/step - loss: 0.3061 - acc: 0.8628 - val_loss: 0.3927 - val_acc: 0.8338
#
# Epoch 00020: saving model to cp/cp.ckpt
# Epoch 21/25
# 250/250 [==============================] - 77s 307ms/step - loss: 0.3038 - acc: 0.8689 - val_loss: 0.3636 - val_acc: 0.8408
#
# Epoch 00021: saving model to cp/cp.ckpt
# Epoch 22/25
# 250/250 [==============================] - 77s 309ms/step - loss: 0.2957 - acc: 0.8685 - val_loss: 0.3818 - val_acc: 0.8408
#
# Epoch 00022: saving model to cp/cp.ckpt
# Epoch 23/25
# 250/250 [==============================] - 78s 310ms/step - loss: 0.2820 - acc: 0.8786 - val_loss: 0.3684 - val_acc: 0.8522
#
# Epoch 00023: saving model to cp/cp.ckpt
# Epoch 24/25
# 250/250 [==============================] - 77s 308ms/step - loss: 0.2810 - acc: 0.8788 - val_loss: 0.4601 - val_acc: 0.8159
#
# Epoch 00024: saving model to cp/cp.ckpt
# Epoch 25/25
# 180/250 [====================>.........] - ETA: 18s - loss: 0.2680 - acc: 0.8873

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('dataset/single_prediction/cat_or_dog_2.jpg', target_size=(128, 128) )
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image,axis=0)
result = classifier.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'
  
print(prediction)

# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# '2.2.4'
